# %%
# !pip install git+https://github.com/pe8sutd/eda4u &> /dev/null
# !git clone https://github.com/pe8sutd/eda4u &> /dev/null
# %load_ext plugin

# %%
# Verilog code and tb for exercise: step one
# %%print_verilog

module top_module( output one);
  assign one = 1'b1;
endmodule

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; wire one_tb;
#
#   top_module top(.one(one_tb));
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 3 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# module top_module( output one);
#   assign one = 1'b1;
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.one_tb']
# time_begin = 0
# time_end = 4
# base = 'dec'

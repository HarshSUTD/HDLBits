# %%
# !pip install git+https://github.com/pe8sutd/eda4u &> /dev/null
# !git clone https://github.com/pe8sutd/eda4u &> /dev/null
# %load_ext plugin

# %%
# module
# %%print_verilog

module top_module ( input a, input b, output out );
    mod_a i1(.out(out), .in1(a), .in2(b));

endmodule

module mod_a ( input in1, input in2, output out );
    // Module body
endmodule
# Out:
# Installing. Please wait... done!

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg a_tb, b_tb; wire out_tb;
#
#   top_module top(.a(a_tb), .b(b_tb), .out(out_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 a_tb = 0; b_tb = 1;
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# module top_module ( input a, input b, output out );
#     mod_a i1(.out(out), .in1(a), .in2(b));
#
# endmodule
#
# module mod_a ( input in1, input in2, output out );
#   // assign out = in1 | in2;
#     // Module body
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_tb', 'tb.a_tb', 'tb.b_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal

# %%
# !pip install git+https://github.com/pe8sutd/eda4u &> /dev/null
# !git clone https://github.com/pe8sutd/eda4u &> /dev/null
# %load_ext plugin

# %%
# vector1
# %%print_verilog
`default_nettype none     // Disable implicit nets. Reduces some types of bugs.
module top_module(
    input wire [15:0] in,
    output wire [7:0] out_hi,
    output wire [7:0] out_lo );

    assign out_hi = in[15:8];
    assign out_lo = in[7:0];

endmodule

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg[15:0] in_tb; wire[7:0] out_hi_tb, out_lo_tb;
#
#   top_module top(.in(in_tb), .out_hi(out_hi_tb), .out_lo(out_lo_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 in_tb = 16'd5557;
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# `default_nettype none     // Disable implicit nets. Reduces some types of bugs.
# module top_module(
#     input wire [15:0] in,
#     output wire [7:0] out_hi,
#     output wire [7:0] out_lo );
#
#     assign out_hi = in[15:8];
#     assign out_lo = in[7:0];
#
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_hi_tb', 'tb.out_lo_tb', 'tb.in_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal

# %%
# vector2
# %%print_verilog

module top_module(
    input [31:0] in,
    output [31:0] out );

    assign out[31:24] = in[7:0];
    assign out[23:16] = in[15:8];
    assign out[15:8] = in[23:16];
    assign out[7:0] = in[31:24];
endmodule
# Out:
# Installing. Please wait... done!

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg[31:0] in_tb; wire[31:0] out_tb;
#
#   top_module top(.in(in_tb), .out(out_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 in_tb = 32'd27;
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# module top_module(
#     input [31:0] in,
#     output [31:0] out );
#
#     assign out[31:24] = in[7:0];
#     assign out[23:16] = in[15:8];
#     assign out[15:8] = in[23:16];
#     assign out[7:0] = in[31:24];
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_tb', 'tb.in_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal

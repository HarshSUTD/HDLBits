# %% [markdown]
# Create a module with one input and one output that behaves like a wire.
#
# ![image.png](
#
# )

# %%
# !pip install git+https://github.com/pe8sutd/eda4u &> /dev/null
# !git clone https://github.com/pe8sutd/eda4u &> /dev/null
# %load_ext plugin

# %%
# %%print_verilog
#
# module top_module( input in, output out );
#         assign out = in;
# endmodule

# %%
#multiple initial blocks present
# %%verilog

//////////////////////////////////////////////////////////
module tb; reg in_tb; wire out_tb;

  top_module top(.in(in_tb), .out(out_tb));

  initial begin
    $dumpfile("tb");
    $dumpvars();

    # 0 in_tb = 0;
    # 1 in_tb = 1;
  end

  initial begin
    # 2 $finish;
  end
//////////////////////////////////////////////////////////

endmodule

//////////////////////////////////////////////////////////
module top_module( input in, output out );
        assign out = in;
endmodule
//////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
#1 initial block present
# %%verilog

//////////////////////////////////////////////////////////
module tb; reg in_tb; wire out_tb;

  top_module top(.in(in_tb), .out(out_tb));

  initial begin
    $dumpfile("tb");
    $dumpvars();

    # 0 in_tb = 0;
    # 1 in_tb = 1;
    # 1 $finish;
  end
//////////////////////////////////////////////////////////

endmodule

//////////////////////////////////////////////////////////
module top_module( input in, output out );
        assign out = in;
endmodule
//////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_tb','tb.in_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal

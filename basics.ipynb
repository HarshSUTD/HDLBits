# %%
# !pip install git+https://github.com/pe8sutd/eda4u &> /dev/null
# !git clone https://github.com/pe8sutd/eda4u &> /dev/null
# %load_ext plugin

# %%
# %%print_verilog
#
# module top_module( input in, output out );
#   assign out = in;
# endmodule
# Out:
# Installing. Please wait... done!

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg in_tb; wire out_tb;
#
#   top_module top(.in(in_tb), .out(out_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 in_tb = 0;
#     # 1 in_tb = 1;
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# module top_module( input in, output out );
#         assign out = in;
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_tb','tb.in_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal

# %%
#Wire4
# %%print_verilog

module top_module(
    input a,b,c,
    output w,x,y,z );

    assign w = a;
    assign x = b;
    assign y = b;
    assign z = c;
endmodule

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg a_tb, b_tb, c_tb; wire w_tb, x_tb, y_tb, z_tb;
#
#   top_module top(.a(a_tb), .b(b_tb), .c(c_tb), .w(w_tb), .x(x_tb), .y(y_tb), .z(z_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 a_tb = 0; b_tb = 1; c_tb = 0;
#
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# module top_module(
#     input a,b,c,
#     output w,x,y,z );
#
#     assign w = a;
#     assign x = b;
#     assign y = b;
#     assign z = c;
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# 1 a_tb, b_tb, c_tb = 1;

# %%
# %%waveform tb.vcd
# sign_list = ['tb.w_tb','tb.x_tb','tb.y_tb','tb.z_tb','tb.a_tb','tb.b_tb','tb.c_tb']
# time_begin = 0
# time_end = 2
# base = 'dec' # bin, dec, dec2, hex, octal

# %%
#NotGate
# %%print_verilog

module top_module( input in, output out );
 assign out = !in;
endmodule

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg in_tb; wire out_tb;
#
#   top_module top(.in(in_tb), .out(out_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 in_tb = 0;
#     # 1 in_tb = 1;
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# module top_module( input in, output out );
#         assign out = !in;
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_tb','tb.in_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal

# %%
#wire_decl
# %%print_verilog

`default_nettype none
module top_module(
    input a,
    input b,
    input c,
    input d,
    output out,
    output out_n   );

    wire and1, and2;

    assign and1 = a & b;
    assign and2 = c & d;
    assign out = and1 | and2;
    assign out_n = ! (and1 | and2);

endmodule

# %%
# %%verilog
#
# //////////////////////////////////////////////////////////
# module tb; reg a_tb, b_tb, c_tb, d_tb; wire out_tb, out_n_tb;
#
#   top_module top(.a(a_tb), .b(b_tb), .c(c_tb), .d(d_tb), .out(out_tb), .out_n(out_n_tb));
#
#   initial begin
#     $dumpfile("tb");
#     $dumpvars();
#
#     # 0 a_tb = 0; b_tb = 1; c_tb = 1; d_tb = 0;
#     # 1 $finish;
#   end
# //////////////////////////////////////////////////////////
#
# endmodule
#
# //////////////////////////////////////////////////////////
# `default_nettype none
# module top_module(
#     input a,
#     input b,
#     input c,
#     input d,
#     output out,
#     output out_n   );
#
#     wire and1, and2;
#
#     assign and1 = a & b;
#     assign and2 = c & d;
#     assign out = and1 | and2;
#     assign out_n = ! (and1 | and2);
#
# endmodule
# //////////////////////////////////////////////////////////
# Out:
# VCD info: dumpfile tb.vcd opened for output.

# %%
# %%waveform tb.vcd
# sign_list = ['tb.out_tb','tb.out_n_tb', 'tb.a_tb', 'tb.b_tb', 'tb.c_tb', 'tb.d_tb']
# time_begin = 0
# time_end = 3
# base = 'dec' # bin, dec, dec2, hex, octal
